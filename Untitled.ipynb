# %%
a=int(input("enter first number :"))
b=int(input("enter second number :"))
ch=int(input("enter your choice\n 1.addition\n 2.substraction\n 3.multiplication\n 4.division\n"))
if ch==1:
        print("sum of two number is",a+b)
elif ch==2:
        print("substration of two number is",a-b)
elif ch==3:
        print("multiplication", a*b)
elif ch==4: 
       print("division", a/b)
else:
    print("invalid choice!!")
# Out:
# enter first number :10
# enter second number :3
# enter your choice
#  1.addition
#  2.substraction
#  3.multiplication
#  4.division
# 5
# invalid choice!!

# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
print("a & b =", a and b)
print("a ! b =", not a)
print("a | b =", a or b)
if a<b:
    print("a")
else:
    print("b")
# Out:
# enter a number:89
# enter a number:12
# a & b = 12
# a ! b = False
# a | b = 89
# b

# %%
a={"rollno":15 , "name":'diya' , "age":22}
b={"name": 'biya', "phone":7736364093 , "place":'kuttikattoor'}
a.update(b)
print(a)
# Out:
# {'rollno': 15, 'name': 'biya', 'age': 22, 'phone': 7736364093, 'place': 'kuttikattoor'}

# %%
list1=[1,2,3]
list2=[6,7,8]
list3=[9,10,11]
list1.remove(1)
print(list1)
list1.pop()
print(list1)
# Out:
# [2, 3]
# [2]
